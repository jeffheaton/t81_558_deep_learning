# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 5: Regularization and Dropout**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 5 Material
#
# * Part 5.1: Part 5.1: Introduction to Regularization: Ridge and Lasso [[Video]](https://www.youtube.com/watch?v=jfgRtCYjoBs&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_05_1_reg_ridge_lasso.ipynb)
# * Part 5.2: Using K-Fold Cross Validation with Keras [[Video]](https://www.youtube.com/watch?v=maiQf8ray_s&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_05_2_kfold.ipynb)
# * Part 5.3: Using L1 and L2 Regularization with Keras to Decrease Overfitting [[Video]](https://www.youtube.com/watch?v=JEWzWv1fBFQ&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_05_3_keras_l1_l2.ipynb)
# * Part 5.4: Drop Out for Keras to Decrease Overfitting [[Video]](https://www.youtube.com/watch?v=bRyOi0L6Rs8&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_05_4_dropout.ipynb)
# * **Part 5.5: Benchmarking Keras Deep Learning Regularization Techniques** [[Video]](https://www.youtube.com/watch?v=1NLBwPumUAs&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_05_5_bootstrap.ipynb)

# %% [markdown]
# # Part 5.5: Benchmarking Keras Deep Learning Regularization Techniques
#
# Quite a few hyperparameters have been introduced so far.  Tweaking each of these values can have an effect on the score obtained by your neural networks.  Some of the hyperparameters seen so far include:
#
# * Number of layers in the neural network
# * How many neurons in each layer
# * What activation functions to use on each layer
# * Dropout percent on each layer
# * L1 and L2 values on each layer
#
# To try out each of these hyperparameters you will need to run train neural networks with multiple settings for each hyperparameter.  However, you may have noticed that neural networks often produce somewhat different results when trained multiple times.  This is because the neural networks start with random weights.  Because of this it is necessary to fit and evaluate a neural network times to ensure that one set of hyperparameters are actually better than another.  Bootstrapping can be an effective means of benchmarking (comparing) two sets of hyperparameters.
#
# Bootstrapping is similar to cross-validation.  Both go through a number of cycles/folds providing validation and training sets.  However, bootstrapping can have an unlimited number of cycles.  Bootstrapping chooses a new train and validation split each cycle, with replacement.  The fact that each cycle is chosen with replacement means that, unlike cross validation, there will often be repeated rows selected between cycles.  If you run the bootstrap for enough cycles, there will be duplicate cycles.
#
# In this part we will use bootstrapping for hyperparameter benchmarking.  We will train a neural network for a specified number of splits (denoted by the SPLITS constant).  For these examples we use 100.  We will compare the average score at the end of the 100.  By the end of the cycles the mean score will have converged somewhat.  This ending score will be a much better basis of comparison than a single cross-validation.  Additionally, the average number of epochs will be tracked to give an idea of a possible optimal value.  Because the early stopping validation set is also used to evaluate the the neural network as well, it might be slightly inflated.  This is because we are both stopping and evaluating on the same sample.  However, we are using the scores only as relative measures to determine the superiority of one set of hyperparameters to another, so this slight inflation should not present too much of a problem.
#
# Because we are benchmarking, we will display the amount of time taken for each cycle.  The following function can be used to nicely format a time span.

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# ### Additional Reading on Hyperparameter Tuning
#
# I will add more here as I encounter additional good sources:
#
# * [A Recipe for Training Neural Networks](http://karpathy.github.io/2019/04/25/recipe/)

# %% [markdown]
# ### Bootstrapping for Regression
#
# Regression bootstrapping uses the **ShuffleSplit** object to perform the splits.  This is similar to **KFold** for cross validation, no balancing takes place.  To demonstrate this technique we will attempt to predict the age column for the jh-simple-dataset this data is loaded by the following code.

# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Generate dummies for product
df = pd.concat([df,pd.get_dummies(df['product'],prefix="product")],axis=1)
df.drop('product', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('age').drop('id')
x = df[x_columns].values
y = df['age'].values

# %% [markdown]
# The following code performs the bootstrap.  The architecture of the neural network can be adjusted to compare many different configurations.

# %%
import pandas as pd
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import ShuffleSplit

SPLITS = 50

# Bootstrap
boot = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=5, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    score = np.sqrt(metrics.mean_squared_error(pred,y_test))
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}, stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}, time={hms_string(time_took)}")
# Out:
# #1: score=0.634184, mean score=0.634184, stdev=0.000000, epochs=132, mean epochs=132, time=0:00:07.34
# #2: score=0.827831, mean score=0.731007, stdev=0.096824, epochs=110, mean epochs=121, time=0:00:05.58
# #3: score=0.776807, mean score=0.746274, stdev=0.081951, epochs=113, mean epochs=118, time=0:00:05.65
# #4: score=0.667571, mean score=0.726598, stdev=0.078730, epochs=137, mean epochs=123, time=0:00:08.99
# #5: score=0.895322, mean score=0.760343, stdev=0.097538, epochs=88, mean epochs=116, time=0:00:06.29
# #6: score=0.853228, mean score=0.775824, stdev=0.095532, epochs=140, mean epochs=120, time=0:00:08.02
# #7: score=0.588680, mean score=0.749089, stdev=0.110050, epochs=120, mean epochs=120, time=0:00:06.52
# #8: score=0.569740, mean score=0.726670, stdev=0.118808, epochs=157, mean epochs=124, time=0:00:08.80
# #9: score=0.803466, mean score=0.735203, stdev=0.114584, epochs=116, mean epochs=123, time=0:00:08.15
# #10: score=1.168158, mean score=0.778499, stdev=0.169372, epochs=108, mean epochs=122, time=0:00:05.57
# #11: score=1.050051, mean score=0.803185, stdev=0.179369, epochs=94, mean epochs=119, time=0:00:04.85
# #12: score=0.765156, mean score=0.800016, stdev=0.172054, epochs=138, mean epochs=121, time=0:00:06.98
# #13: score=0.658341, mean score=0.789118, stdev=0.169561, epochs=104, mean epochs=119, time=0:00:05.37
# #14: score=1.080256, mean score=0.809914, stdev=0.179775, epochs=115, mean epochs=119, time=0:00:06.49
# #15: score=0.601163, mean score=0.795997, stdev=0.181317, epochs=122, mean epochs=119, time=0:00:06.16
# #16: score=0.765693, mean score=0.794103, stdev=0.175713, epochs=120, mean epochs=119, time=0:00:06.94
# #17: score=0.769433, mean score=0.792652, stdev=0.170565, epochs=106, mean epochs=118, time=0:00:05.96
# #18: score=1.043511, mean score=0.806588, stdev=0.175437, epochs=115, mean epochs=118, time=0:00:07.52
# #19: score=0.698322, mean score=0.800890, stdev=0.172461, epochs=167, mean epochs=121, time=0:00:08.48
# #20: score=0.744044, mean score=0.798048, stdev=0.168550, epochs=117, mean epochs=120, time=0:00:05.88
# #21: score=0.957391, mean score=0.805636, stdev=0.167952, epochs=88, mean epochs=119, time=0:00:04.54
# #22: score=0.513077, mean score=0.792338, stdev=0.175041, epochs=118, mean epochs=119, time=0:00:05.89
# #23: score=0.805863, mean score=0.792926, stdev=0.171215, epochs=112, mean epochs=119, time=0:00:05.75
# #24: score=0.635249, mean score=0.786356, stdev=0.170546, epochs=111, mean epochs=118, time=0:00:06.14
# #25: score=0.600427, mean score=0.778919, stdev=0.171026, epochs=130, mean epochs=119, time=0:00:06.39
# #26: score=0.741770, mean score=0.777490, stdev=0.167857, epochs=112, mean epochs=118, time=0:00:05.71
# #27: score=0.712436, mean score=0.775080, stdev=0.165177, epochs=115, mean epochs=118, time=0:00:05.80
# #28: score=0.817891, mean score=0.776609, stdev=0.162395, epochs=118, mean epochs=118, time=0:00:06.16
# #29: score=0.512802, mean score=0.767513, stdev=0.166673, epochs=137, mean epochs=119, time=0:00:06.71
# #30: score=0.702320, mean score=0.765339, stdev=0.164289, epochs=104, mean epochs=118, time=0:00:05.22
# #31: score=0.622396, mean score=0.760728, stdev=0.163579, epochs=129, mean epochs=119, time=0:00:07.48
# #32: score=0.516800, mean score=0.753106, stdev=0.166503, epochs=130, mean epochs=119, time=0:00:07.57
# #33: score=0.735319, mean score=0.752567, stdev=0.163989, epochs=133, mean epochs=119, time=0:00:06.85
# #34: score=1.047268, mean score=0.761234, stdev=0.169058, epochs=104, mean epochs=119, time=0:00:05.25
# #35: score=0.646516, mean score=0.757957, stdev=0.167718, epochs=124, mean epochs=119, time=0:00:06.17
# #36: score=0.578980, mean score=0.752985, stdev=0.167967, epochs=94, mean epochs=118, time=0:00:04.87
# #37: score=1.061023, mean score=0.761310, stdev=0.173048, epochs=87, mean epochs=117, time=0:00:04.77
# #38: score=0.622299, mean score=0.757652, stdev=0.172200, epochs=153, mean epochs=118, time=0:00:07.42
# #39: score=0.619913, mean score=0.754120, stdev=0.171366, epochs=124, mean epochs=119, time=0:00:06.32
# #40: score=0.597396, mean score=0.750202, stdev=0.170971, epochs=165, mean epochs=120, time=0:00:08.01
# #41: score=1.201102, mean score=0.761200, stdev=0.182636, epochs=116, mean epochs=120, time=0:00:05.87
# #42: score=0.544736, mean score=0.756046, stdev=0.183441, epochs=105, mean epochs=119, time=0:00:05.33
# #43: score=0.727620, mean score=0.755385, stdev=0.181346, epochs=123, mean epochs=119, time=0:00:06.14
# #44: score=0.739274, mean score=0.755019, stdev=0.179290, epochs=112, mean epochs=119, time=0:00:05.95
# #45: score=1.123390, mean score=0.763205, stdev=0.185416, epochs=89, mean epochs=118, time=0:00:04.79
# #46: score=0.661628, mean score=0.760997, stdev=0.183987, epochs=114, mean epochs=118, time=0:00:05.75
# #47: score=0.580085, mean score=0.757147, stdev=0.183882, epochs=144, mean epochs=119, time=0:00:07.14
# #48: score=0.873597, mean score=0.759573, stdev=0.182715, epochs=91, mean epochs=118, time=0:00:04.71
# #49: score=1.045215, mean score=0.765403, stdev=0.185296, epochs=145, mean epochs=119, time=0:00:07.10
# #50: score=0.666889, mean score=0.763433, stdev=0.183951, epochs=155, mean epochs=120, time=0:00:07.93

# %% [markdown]
# The bootstrapping process for classification is similar and is presented in the next section.

# %% [markdown]
# ### Bootstrapping for Classification
#
# Regression bootstrapping uses the **StratifiedShuffleSplit** object to perform the splits.  This is similar to **StratifiedKFold** for cross validation, as the classes are balanced so that the sampling has no effect on proportions.  To demonstrate this technique we will attempt to predict the product column for the jh-simple-dataset this data is loaded by the following code.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %%
import pandas as pd
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit

SPLITS = 50

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
    model.add(Dense(25, activation='relu')) # Hidden 2
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=25, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}, stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}, time={hms_string(time_took)}")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 13:17:04.833148 140736216040320 deprecation.py:323] From /Users/jheaton/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# #1: score=0.693681, mean score=0.693681, stdev=0.000000, epochs=66, mean epochs=66, time=0:00:03.94
# #2: score=0.662767, mean score=0.678224, stdev=0.015457, epochs=52, mean epochs=59, time=0:00:03.43
# #3: score=0.673585, mean score=0.676678, stdev=0.012809, epochs=49, mean epochs=55, time=0:00:03.04
# #4: score=0.638130, mean score=0.667041, stdev=0.020042, epochs=77, mean epochs=61, time=0:00:04.44
# #5: score=0.673175, mean score=0.668268, stdev=0.018093, epochs=79, mean epochs=64, time=0:00:05.60
# #6: score=0.698562, mean score=0.673317, stdev=0.020007, epochs=50, mean epochs=62, time=0:00:03.13
# #7: score=0.680268, mean score=0.674310, stdev=0.018682, epochs=63, mean epochs=62, time=0:00:04.05
# #8: score=0.738749, mean score=0.682365, stdev=0.027560, epochs=60, mean epochs=62, time=0:00:03.62
# #9: score=0.601357, mean score=0.673364, stdev=0.036377, epochs=88, mean epochs=64, time=0:00:04.96
# #10: score=0.636355, mean score=0.669663, stdev=0.036252, epochs=99, mean epochs=68, time=0:00:05.45
# #11: score=0.673932, mean score=0.670051, stdev=0.034587, epochs=109, mean epochs=72, time=0:00:07.11
# #12: score=0.751534, mean score=0.676841, stdev=0.040047, epochs=42, mean epochs=69, time=0:00:02.71
# #13: score=0.707254, mean score=0.679181, stdev=0.039320, epochs=60, mean epochs=68, time=0:00:03.60
# #14: score=0.742509, mean score=0.683704, stdev=0.041251, epochs=49, mean epochs=67, time=0:00:03.34
# #15: score=0.678523, mean score=0.683359, stdev=0.039873, epochs=50, mean epochs=66, time=0:00:03.19
# #16: score=0.752536, mean score=0.687682, stdev=0.042082, epochs=47, mean epochs=65, time=0:00:03.07
# #17: score=0.610290, mean score=0.683130, stdev=0.044703, epochs=109, mean epochs=67, time=0:00:06.09
# #18: score=0.645846, mean score=0.681059, stdev=0.044275, epochs=63, mean epochs=67, time=0:00:04.00
# #19: score=0.608141, mean score=0.677221, stdev=0.046067, epochs=47, mean epochs=66, time=0:00:02.98
# #20: score=0.693606, mean score=0.678040, stdev=0.045042, epochs=51, mean epochs=65, time=0:00:03.16
# #21: score=0.657924, mean score=0.677082, stdev=0.044165, epochs=58, mean epochs=65, time=0:00:03.76
# #22: score=0.719962, mean score=0.679031, stdev=0.044064, epochs=64, mean epochs=65, time=0:00:03.85
# #23: score=0.570421, mean score=0.674309, stdev=0.048454, epochs=81, mean epochs=65, time=0:00:04.62
# #24: score=0.731938, mean score=0.676710, stdev=0.048812, epochs=53, mean epochs=65, time=0:00:03.23
# #25: score=0.601554, mean score=0.673704, stdev=0.050042, epochs=66, mean epochs=65, time=0:00:03.87
# #26: score=0.662636, mean score=0.673278, stdev=0.049116, epochs=66, mean epochs=65, time=0:00:03.90
# #27: score=0.691750, mean score=0.673962, stdev=0.048324, epochs=74, mean epochs=65, time=0:00:04.31
# #28: score=0.731931, mean score=0.676033, stdev=0.048658, epochs=58, mean epochs=65, time=0:00:03.50
# #29: score=0.649527, mean score=0.675119, stdev=0.048055, epochs=53, mean epochs=64, time=0:00:03.26
# #30: score=0.732376, mean score=0.677027, stdev=0.048353, epochs=48, mean epochs=64, time=0:00:03.30
# #31: score=0.701127, mean score=0.677805, stdev=0.047757, epochs=62, mean epochs=64, time=0:00:03.73
# #32: score=0.695905, mean score=0.678370, stdev=0.047110, epochs=65, mean epochs=64, time=0:00:03.84
# #33: score=0.603517, mean score=0.676102, stdev=0.048132, epochs=82, mean epochs=64, time=0:00:04.80
# #34: score=0.576023, mean score=0.673159, stdev=0.050344, epochs=80, mean epochs=65, time=0:00:04.59
# #35: score=0.504797, mean score=0.668348, stdev=0.056999, epochs=90, mean epochs=66, time=0:00:05.53
# #36: score=0.637926, mean score=0.667503, stdev=0.056423, epochs=79, mean epochs=66, time=0:00:04.54
# #37: score=0.681377, mean score=0.667878, stdev=0.055701, epochs=41, mean epochs=65, time=0:00:02.70
# #38: score=0.703076, mean score=0.668804, stdev=0.055251, epochs=46, mean epochs=65, time=0:00:02.93
# #39: score=0.751519, mean score=0.670925, stdev=0.056083, epochs=57, mean epochs=64, time=0:00:03.79
# #40: score=0.701170, mean score=0.671681, stdev=0.055579, epochs=35, mean epochs=64, time=0:00:02.44
# #41: score=0.730218, mean score=0.673109, stdev=0.055635, epochs=51, mean epochs=63, time=0:00:03.16
# #42: score=0.665175, mean score=0.672920, stdev=0.054982, epochs=47, mean epochs=63, time=0:00:02.98
# #43: score=0.680935, mean score=0.673107, stdev=0.054352, epochs=50, mean epochs=63, time=0:00:03.17
# #44: score=0.762621, mean score=0.675141, stdev=0.055362, epochs=40, mean epochs=62, time=0:00:02.64
# #45: score=0.625836, mean score=0.674045, stdev=0.055224, epochs=76, mean epochs=62, time=0:00:04.39
# #46: score=0.686592, mean score=0.674318, stdev=0.054651, epochs=38, mean epochs=62, time=0:00:03.04
# #47: score=0.673410, mean score=0.674299, stdev=0.054067, epochs=61, mean epochs=62, time=0:00:03.73
# #48: score=0.732717, mean score=0.675516, stdev=0.054147, epochs=91, mean epochs=62, time=0:00:05.20
# #49: score=0.669272, mean score=0.675388, stdev=0.053599, epochs=66, mean epochs=63, time=0:00:04.37
# #50: score=0.670525, mean score=0.675291, stdev=0.053065, epochs=44, mean epochs=62, time=0:00:02.88

# %% [markdown]
# ### Benchmarking
#
# Now that we've seen how to bootstrap with both classification and regression we can start to try to optimize the hyperparameters for the jh-simple-dataset data.  For this example we will encode for classification of the product column.  Evaluation will be in log loss.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %% [markdown]
# I performed some optimization and the code is currently set to the best settings that I came up with. Later in this course we will see how we can use an automatic process to optimize the hyperparameters.

# %%
import pandas as pd
import os
import numpy as np
import time
import tensorflow.keras.initializers
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import LeakyReLU,PReLU

SPLITS = 100

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    # kernel_initializer = tensorflow.keras.initializers.he_uniform(seed=None)
    model = Sequential()
    model.add(Dense(100, input_dim=x.shape[1], activation=PReLU(), kernel_regularizer=regularizers.l2(1e-4)
    )) # Hidden 1
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), activity_regularizer=regularizers.l2(1e-4)
    )) # Hidden 2
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), activity_regularizer=regularizers.l2(1e-4)
    )) # Hidden 3
#    model.add(Dropout(0.5)) - Usually better performance without dropout on final layer
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=100, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}, stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}, time={hms_string(time_took)}")
# https://towardsdatascience.com/hyper-parameters-in-action-part-ii-weight-initializers-35aee1a28404

# 100 Prelu 0.5 1-2, He init
# Bootstrap #100: Log Loss score=0.604399, mean score=0.651921, stdev=0.045944 epochs=298, time=0:00:40.12
# 100 Prelu 0.5 1-2
# Bootstrap #53: Log Loss score=0.652944, mean score=0.655620, stdev=0.050328 epochs=269, time=0:00:51.02
# Out:
# #1: score=0.617918, mean score=0.617918, stdev=0.000000, epochs=225, mean epochs=225, time=0:00:19.51
# #2: score=0.532705, mean score=0.575311, stdev=0.042606, epochs=257, mean epochs=241, time=0:00:23.10
# #3: score=0.689949, mean score=0.613524, stdev=0.064269, epochs=180, mean epochs=220, time=0:00:17.36
# #4: score=0.705360, mean score=0.636483, stdev=0.068405, epochs=136, mean epochs=199, time=0:00:12.70
# #5: score=0.706968, mean score=0.650580, stdev=0.067367, epochs=163, mean epochs=192, time=0:00:15.28
# #6: score=0.670541, mean score=0.653907, stdev=0.061946, epochs=199, mean epochs=193, time=0:00:18.60
# #7: score=0.605729, mean score=0.647024, stdev=0.059777, epochs=190, mean epochs=192, time=0:00:17.11
# #8: score=0.684964, mean score=0.651767, stdev=0.057307, epochs=180, mean epochs=191, time=0:00:16.47
# #9: score=0.596459, mean score=0.645621, stdev=0.056756, epochs=160, mean epochs=187, time=0:00:14.56
# #10: score=0.683502, mean score=0.649409, stdev=0.055030, epochs=203, mean epochs=189, time=0:00:18.46
# #11: score=0.574136, mean score=0.642566, stdev=0.056756, epochs=266, mean epochs=196, time=0:00:24.67
# #12: score=0.714384, mean score=0.648551, stdev=0.057852, epochs=138, mean epochs=191, time=0:00:14.31
# #13: score=0.606264, mean score=0.645298, stdev=0.056713, epochs=187, mean epochs=191, time=0:00:18.58
# #14: score=0.725613, mean score=0.651035, stdev=0.058433, epochs=145, mean epochs=187, time=0:00:14.06
# #15: score=0.651163, mean score=0.651044, stdev=0.056452, epochs=188, mean epochs=187, time=0:00:17.66
# #16: score=0.630207, mean score=0.649741, stdev=0.054892, epochs=159, mean epochs=186, time=0:00:15.24
# #17: score=0.704633, mean score=0.652970, stdev=0.054797, epochs=143, mean epochs=183, time=0:00:15.58
# #18: score=0.654308, mean score=0.653045, stdev=0.053254, epochs=222, mean epochs=185, time=0:00:20.82
# #19: score=0.688572, mean score=0.654914, stdev=0.052437, epochs=176, mean epochs=185, time=0:00:17.84
# #20: score=0.620214, mean score=0.653179, stdev=0.051666, epochs=202, mean epochs=185, time=0:00:19.27
# #21: score=0.677203, mean score=0.654323, stdev=0.050679, epochs=150, mean epochs=184, time=0:00:14.76
# #22: score=0.616373, mean score=0.652598, stdev=0.050141, epochs=193, mean epochs=184, time=0:00:17.90
# #23: score=0.697336, mean score=0.654543, stdev=0.049880, epochs=282, mean epochs=188, time=0:00:24.35
# #24: score=0.568733, mean score=0.650968, stdev=0.051753, epochs=233, mean epochs=190, time=0:00:24.10
# #25: score=0.615114, mean score=0.649534, stdev=0.051192, epochs=262, mean epochs=193, time=0:00:23.39
# #26: score=0.697872, mean score=0.651393, stdev=0.051052, epochs=163, mean epochs=192, time=0:00:15.33
# #27: score=0.570679, mean score=0.648404, stdev=0.052365, epochs=338, mean epochs=197, time=0:00:29.35
# #28: score=0.614037, mean score=0.647176, stdev=0.051815, epochs=243, mean epochs=199, time=0:00:25.71
# #29: score=0.673698, mean score=0.648091, stdev=0.051144, epochs=149, mean epochs=197, time=0:00:14.81
# #30: score=0.788823, mean score=0.652782, stdev=0.056273, epochs=144, mean epochs=195, time=0:00:13.73
# #31: score=0.668585, mean score=0.653292, stdev=0.055428, epochs=189, mean epochs=195, time=0:00:19.33
# #32: score=0.632373, mean score=0.652638, stdev=0.054677, epochs=253, mean epochs=197, time=0:00:27.76
# #33: score=0.614357, mean score=0.651478, stdev=0.054240, epochs=210, mean epochs=197, time=0:00:24.27
# #34: score=0.668184, mean score=0.651969, stdev=0.053511, epochs=142, mean epochs=196, time=0:00:15.83
# #35: score=0.621896, mean score=0.651110, stdev=0.052979, epochs=311, mean epochs=199, time=0:00:33.10
# #36: score=0.559718, mean score=0.648571, stdev=0.054354, epochs=361, mean epochs=203, time=0:00:40.15
# #37: score=0.655152, mean score=0.648749, stdev=0.053625, epochs=137, mean epochs=202, time=0:00:16.06
# #38: score=0.720940, mean score=0.650649, stdev=0.054162, epochs=142, mean epochs=200, time=0:00:14.59
# #39: score=0.761919, mean score=0.653502, stdev=0.056281, epochs=127, mean epochs=198, time=0:00:13.18
# #40: score=0.638436, mean score=0.653125, stdev=0.055623, epochs=218, mean epochs=199, time=0:00:20.63
# #41: score=0.573743, mean score=0.651189, stdev=0.056289, epochs=157, mean epochs=198, time=0:00:16.53
# #42: score=0.637974, mean score=0.650875, stdev=0.055651, epochs=162, mean epochs=197, time=0:00:15.80
# #43: score=0.715549, mean score=0.652379, stdev=0.055857, epochs=136, mean epochs=195, time=0:00:13.75
# #44: score=0.738378, mean score=0.654333, stdev=0.056687, epochs=195, mean epochs=195, time=0:00:18.97
# #45: score=0.724016, mean score=0.655882, stdev=0.056987, epochs=167, mean epochs=195, time=0:00:16.73
# #46: score=0.658742, mean score=0.655944, stdev=0.056365, epochs=152, mean epochs=194, time=0:00:15.38
# #47: score=0.642868, mean score=0.655666, stdev=0.055794, epochs=266, mean epochs=195, time=0:00:27.62
# #48: score=0.560590, mean score=0.653685, stdev=0.056856, epochs=208, mean epochs=196, time=0:00:23.82
# #49: score=0.569452, mean score=0.651966, stdev=0.057519, epochs=208, mean epochs=196, time=0:00:25.57
# #50: score=0.640846, mean score=0.651743, stdev=0.056962, epochs=163, mean epochs=195, time=0:00:20.40
# #51: score=0.703516, mean score=0.652759, stdev=0.056856, epochs=168, mean epochs=195, time=0:00:18.55
# #52: score=0.636249, mean score=0.652441, stdev=0.056352, epochs=223, mean epochs=195, time=0:00:26.65
# #53: score=0.653137, mean score=0.652454, stdev=0.055818, epochs=143, mean epochs=194, time=0:00:17.98
# #54: score=0.605244, mean score=0.651580, stdev=0.055664, epochs=227, mean epochs=195, time=0:00:26.51
# #55: score=0.576854, mean score=0.650221, stdev=0.056052, epochs=276, mean epochs=196, time=0:00:30.62
# #56: score=0.617533, mean score=0.649638, stdev=0.055718, epochs=190, mean epochs=196, time=0:00:22.26
# #57: score=0.682027, mean score=0.650206, stdev=0.055390, epochs=187, mean epochs=196, time=0:00:21.92
# #58: score=0.653244, mean score=0.650258, stdev=0.054912, epochs=172, mean epochs=195, time=0:00:20.75
# #59: score=0.617699, mean score=0.649706, stdev=0.054607, epochs=210, mean epochs=196, time=0:00:24.91
# #60: score=0.541008, mean score=0.647895, stdev=0.055909, epochs=255, mean epochs=197, time=0:00:28.76
# #61: score=0.681536, mean score=0.648446, stdev=0.055613, epochs=153, mean epochs=196, time=0:00:20.03
# #62: score=0.666886, mean score=0.648744, stdev=0.055212, epochs=187, mean epochs=196, time=0:00:22.64
# #63: score=0.703106, mean score=0.649607, stdev=0.055192, epochs=177, mean epochs=196, time=0:00:21.27
# #64: score=0.619733, mean score=0.649140, stdev=0.054884, epochs=178, mean epochs=195, time=0:00:20.82
# #65: score=0.654266, mean score=0.649219, stdev=0.054464, epochs=212, mean epochs=195, time=0:00:20.89
# #66: score=0.597240, mean score=0.648431, stdev=0.054421, epochs=184, mean epochs=195, time=0:00:18.16
# #67: score=0.640410, mean score=0.648311, stdev=0.054023, epochs=168, mean epochs=195, time=0:00:16.65
# #68: score=0.740366, mean score=0.649665, stdev=0.054757, epochs=136, mean epochs=194, time=0:00:14.39
# #69: score=0.602370, mean score=0.648980, stdev=0.054652, epochs=180, mean epochs=194, time=0:00:18.11
# #70: score=0.632369, mean score=0.648742, stdev=0.054296, epochs=175, mean epochs=194, time=0:00:17.42
# #71: score=0.698194, mean score=0.649439, stdev=0.054226, epochs=128, mean epochs=193, time=0:00:13.52
# #72: score=0.740777, mean score=0.650707, stdev=0.054899, epochs=141, mean epochs=192, time=0:00:14.89
# #73: score=0.626572, mean score=0.650377, stdev=0.054594, epochs=232, mean epochs=192, time=0:00:26.48
# #74: score=0.627211, mean score=0.650064, stdev=0.054289, epochs=271, mean epochs=193, time=0:00:30.37
# #75: score=0.662386, mean score=0.650228, stdev=0.053945, epochs=185, mean epochs=193, time=0:00:22.93
# #76: score=0.661056, mean score=0.650371, stdev=0.053603, epochs=245, mean epochs=194, time=0:00:30.02
# #77: score=0.641131, mean score=0.650251, stdev=0.053264, epochs=253, mean epochs=195, time=0:00:28.11
# #78: score=0.618176, mean score=0.649839, stdev=0.053044, epochs=209, mean epochs=195, time=0:00:23.43
# #79: score=0.698254, mean score=0.650452, stdev=0.052985, epochs=130, mean epochs=194, time=0:00:18.84
# #80: score=0.639038, mean score=0.650310, stdev=0.052668, epochs=169, mean epochs=194, time=0:00:19.24
# #81: score=0.740532, mean score=0.651423, stdev=0.053281, epochs=179, mean epochs=194, time=0:00:20.34
# #82: score=0.689347, mean score=0.651886, stdev=0.053119, epochs=170, mean epochs=193, time=0:00:17.66
# #83: score=0.617848, mean score=0.651476, stdev=0.052928, epochs=253, mean epochs=194, time=0:00:24.27
# #84: score=0.607723, mean score=0.650955, stdev=0.052826, epochs=189, mean epochs=194, time=0:00:19.34
# #85: score=0.659030, mean score=0.651050, stdev=0.052521, epochs=213, mean epochs=194, time=0:00:27.79
# #86: score=0.678870, mean score=0.651373, stdev=0.052300, epochs=166, mean epochs=194, time=0:00:17.44
# #87: score=0.660406, mean score=0.651477, stdev=0.052008, epochs=138, mean epochs=193, time=0:00:14.93
# #88: score=0.634616, mean score=0.651286, stdev=0.051742, epochs=222, mean epochs=194, time=0:00:25.15
# #89: score=0.644994, mean score=0.651215, stdev=0.051455, epochs=154, mean epochs=193, time=0:00:16.59
# #90: score=0.594363, mean score=0.650583, stdev=0.051514, epochs=220, mean epochs=193, time=0:00:21.82
# #91: score=0.663881, mean score=0.650729, stdev=0.051249, epochs=238, mean epochs=194, time=0:00:23.24
# #92: score=0.710045, mean score=0.651374, stdev=0.051340, epochs=154, mean epochs=193, time=0:00:19.08
# #93: score=0.676931, mean score=0.651649, stdev=0.051131, epochs=179, mean epochs=193, time=0:00:22.48
# #94: score=0.647165, mean score=0.651601, stdev=0.050860, epochs=190, mean epochs=193, time=0:00:19.37
# #95: score=0.695665, mean score=0.652065, stdev=0.050791, epochs=152, mean epochs=193, time=0:00:16.33
# #96: score=0.706006, mean score=0.652627, stdev=0.050822, epochs=175, mean epochs=193, time=0:00:18.07
# #97: score=0.697649, mean score=0.653091, stdev=0.050763, epochs=174, mean epochs=192, time=0:00:18.43
# #98: score=0.642125, mean score=0.652979, stdev=0.050516, epochs=178, mean epochs=192, time=0:00:20.02
# #99: score=0.638461, mean score=0.652833, stdev=0.050281, epochs=183, mean epochs=192, time=0:00:19.51
# #100: score=0.600102, mean score=0.652305, stdev=0.050303, epochs=198, mean epochs=192, time=0:00:23.98
