# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 8: Kaggle Data Sets**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 8 Material
#
# * Part 8.1: Introduction to Kaggle [[Video]](https://www.youtube.com/watch?v=v4lJBhdCuCU&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_08_1_kaggle_intro.ipynb)
# * **Part 8.2: Building Ensembles with Scikit-Learn and Keras** [[Video]](https://www.youtube.com/watch?v=LQ-9ZRBLasw&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_08_2_keras_ensembles.ipynb)
# * Part 8.3: How Should you Architect Your Keras Neural Network: Hyperparameters [[Video]](https://www.youtube.com/watch?v=1q9klwSoUQw&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_08_3_keras_hyperparameters.ipynb)
# * Part 8.4: Bayesian Hyperparameter Optimization for Keras [[Video]](https://www.youtube.com/watch?v=sXdxyUCCm8s&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_08_4_bayesian_hyperparameter_opt.ipynb)
# * Part 8.5: Current Semester's Kaggle [[Video]](https://www.youtube.com/watch?v=48OrNYYey5E) [[Notebook]](t81_558_class_08_5_kaggle_project.ipynb)

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# # Part 8.2: Building Ensembles with Scikit-Learn and Keras
#
# ### Evaluating Feature Importance
#
# Feature importance tells us how important each of the features (from the feature/import vector are to the prediction of a neural network, or other model.  There are many different ways to evaluate feature importance for neural networks.  The following paper presents a very good (and readable) overview of the various means of evaluating the importance of neural network inputs/features.
#
# Olden, J. D., Joy, M. K., & Death, R. G. (2004). [An accurate comparison of methods for quantifying variable importance in artificial neural networks using simulated data](http://depts.washington.edu/oldenlab/wordpress/wp-content/uploads/2013/03/EcologicalModelling_2004.pdf). *Ecological Modelling*, 178(3), 389-397.
#
# In summary, the following methods are available to neural networks:
#
# * Connection Weights Algorithm
# * Partial Derivatives
# * Input Perturbation
# * Sensitivity Analysis
# * Forward Stepwise Addition
# * Improved Stepwise Selection 1
# * Backward Stepwise Elimination
# * Improved Stepwise Selection
#
# For this class we will use the **Input Perturbation** feature ranking algorithm.  This algorithm will work with any regression or classification network.  implementation of the input perturbation algorithm for scikit-learn is given in the next section. This algorithm is implemented in a function below that will work with any scikit-learn model.
#
# This algorithm was introduced by [Breiman](https://en.wikipedia.org/wiki/Leo_Breiman) in his seminal paper on random forests.  Although he presented this algorithm in conjunction with random forests, it is model-independent and appropriate for any supervised learning model.  This algorithm, known as the input perturbation algorithm, works by evaluating a trained model’s accuracy with each of the inputs individually shuffled from a data set.  Shuffling an input causes it to become useless—effectively removing it from the model. More important inputs will produce a less accurate score when they are removed by shuffling them. This process makes sense, because important features will contribute to the accuracy of the model.  The TensorFlow version of this algorithm is taken from the following paper.
#
# Heaton, J., McElwee, S., & Cannady, J. (May 2017). Early stabilizing feature importance for TensorFlow deep neural networks. In *International Joint Conference on Neural Networks (IJCNN 2017)* (accepted for publication). IEEE.
#
# This algorithm will use logloss to evaluate a classification problem and RMSE for regression.

# %%
from sklearn import metrics
import scipy as sp
import numpy as np
import math
from sklearn import metrics

def perturbation_rank(model, x, y, names, regression):
    errors = []

    for i in range(x.shape[1]):
        hold = np.array(x[:, i])
        np.random.shuffle(x[:, i])
        
        if regression:
            pred = model.predict(x)
            error = metrics.mean_squared_error(y, pred)
        else:
            pred = model.predict_proba(x)
            error = metrics.log_loss(y, pred)
            
        errors.append(error)
        x[:, i] = hold
        
    max_error = np.max(errors)
    importance = [e/max_error for e in errors]

    data = {'name':names,'error':errors,'importance':importance}
    result = pd.DataFrame(data, columns = ['name','error','importance'])
    result.sort_values(by=['importance'], ascending=[0], inplace=True)
    result.reset_index(inplace=True, drop=True)
    return result

# %% [markdown]
# ### Classification and Input Perturbation Ranking

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build neural network
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(x_train,y_train,verbose=2,epochs=100)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 15:14:28.751466 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:28.882447 12720 deprecation.py:323] From C:\Users\jheaton\AppData\Local\Continuum\miniconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:466: BaseResourceVariable.constraint (from tensorflow.python.ops.resource_variable_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Apply a constraint manually following the optimizer update step.
# Epoch 1/100
# 112/112 - 1s - loss: 1.2174
# Epoch 2/100
# 112/112 - 0s - loss: 1.0857
# Epoch 3/100
# 112/112 - 0s - loss: 1.0299
# Epoch 4/100
# 112/112 - 0s - loss: 0.9896
# Epoch 5/100
# 112/112 - 0s - loss: 0.9515
# Epoch 6/100
# 112/112 - 0s - loss: 0.9139
# Epoch 7/100
# 112/112 - 0s - loss: 0.8793
# Epoch 8/100
# 112/112 - 0s - loss: 0.8433
# Epoch 9/100
# 112/112 - 0s - loss: 0.8144
# Epoch 10/100
# 112/112 - 0s - loss: 0.7815
# Epoch 11/100
# 112/112 - 0s - loss: 0.7521
# Epoch 12/100
# 112/112 - 0s - loss: 0.7203
# Epoch 13/100
# 112/112 - 0s - loss: 0.6933
# Epoch 14/100
# 112/112 - 0s - loss: 0.6650
# Epoch 15/100
# 112/112 - 0s - loss: 0.6376
# Epoch 16/100
# 112/112 - 0s - loss: 0.6142
# Epoch 17/100
# 112/112 - 0s - loss: 0.5917
# Epoch 18/100
# 112/112 - 0s - loss: 0.5702
# Epoch 19/100
# 112/112 - 0s - loss: 0.5507
# Epoch 20/100
# 112/112 - 0s - loss: 0.5329
# Epoch 21/100
# 112/112 - 0s - loss: 0.5157
# Epoch 22/100
# 112/112 - 0s - loss: 0.4992
# Epoch 23/100
# 112/112 - 0s - loss: 0.4858
# Epoch 24/100
# 112/112 - 0s - loss: 0.4705
# Epoch 25/100
# 112/112 - 0s - loss: 0.4557
# Epoch 26/100
# 112/112 - 0s - loss: 0.4425
# Epoch 27/100
# 112/112 - 0s - loss: 0.4329
# Epoch 28/100
# 112/112 - 0s - loss: 0.4167
# Epoch 29/100
# 112/112 - 0s - loss: 0.4079
# Epoch 30/100
# 112/112 - 0s - loss: 0.3972
# Epoch 31/100
# 112/112 - 0s - loss: 0.3866
# Epoch 32/100
# 112/112 - 0s - loss: 0.3775
# Epoch 33/100
# 112/112 - 0s - loss: 0.3674
# Epoch 34/100
# 112/112 - 0s - loss: 0.3574
# Epoch 35/100
# 112/112 - 0s - loss: 0.3471
# Epoch 36/100
# 112/112 - 0s - loss: 0.3400
# Epoch 37/100
# 112/112 - 0s - loss: 0.3290
# Epoch 38/100
# 112/112 - 0s - loss: 0.3211
# Epoch 39/100
# 112/112 - 0s - loss: 0.3141
# Epoch 40/100
# 112/112 - 0s - loss: 0.3075
# Epoch 41/100
# 112/112 - 0s - loss: 0.2985
# Epoch 42/100
# 112/112 - 0s - loss: 0.2901
# Epoch 43/100
# 112/112 - 0s - loss: 0.2852
# Epoch 44/100
# 112/112 - 0s - loss: 0.2796
# Epoch 45/100
# 112/112 - 0s - loss: 0.2742
# Epoch 46/100
# 112/112 - 0s - loss: 0.2632
# Epoch 47/100
# 112/112 - 0s - loss: 0.2556
# Epoch 48/100
# 112/112 - 0s - loss: 0.2528
# Epoch 49/100
# 112/112 - 0s - loss: 0.2471
# Epoch 50/100
# 112/112 - 0s - loss: 0.2407
# Epoch 51/100
# 112/112 - 0s - loss: 0.2338
# Epoch 52/100
# 112/112 - 0s - loss: 0.2346
# Epoch 53/100
# 112/112 - 0s - loss: 0.2221
# Epoch 54/100
# 112/112 - 0s - loss: 0.2227
# Epoch 55/100
# 112/112 - 0s - loss: 0.2098
# Epoch 56/100
# 112/112 - 0s - loss: 0.2173
# Epoch 57/100
# 112/112 - 0s - loss: 0.2105
# Epoch 58/100
# 112/112 - 0s - loss: 0.1997
# Epoch 59/100
# 112/112 - 0s - loss: 0.1969
# Epoch 60/100
# 112/112 - 0s - loss: 0.1908
# Epoch 61/100
# 112/112 - 0s - loss: 0.1885
# Epoch 62/100
# 112/112 - 0s - loss: 0.1832
# Epoch 63/100
# 112/112 - 0s - loss: 0.1802
# Epoch 64/100
# 112/112 - 0s - loss: 0.1771
# Epoch 65/100
# 112/112 - 0s - loss: 0.1737
# Epoch 66/100
# 112/112 - 0s - loss: 0.1702
# Epoch 67/100
# 112/112 - 0s - loss: 0.1670
# Epoch 68/100
# 112/112 - 0s - loss: 0.1648
# Epoch 69/100
# 112/112 - 0s - loss: 0.1617
# Epoch 70/100
# 112/112 - 0s - loss: 0.1586
# Epoch 71/100
# 112/112 - 0s - loss: 0.1560
# Epoch 72/100
# 112/112 - 0s - loss: 0.1532
# Epoch 73/100
# 112/112 - 0s - loss: 0.1493
# Epoch 74/100
# 112/112 - 0s - loss: 0.1587
# Epoch 75/100
# 112/112 - 0s - loss: 0.1423
# Epoch 76/100
# 112/112 - 0s - loss: 0.1529
# Epoch 77/100
# 112/112 - 0s - loss: 0.1449
# Epoch 78/100
# 112/112 - 0s - loss: 0.1462
# Epoch 79/100
# 112/112 - 0s - loss: 0.1439
# Epoch 80/100
# 112/112 - 0s - loss: 0.1363
# Epoch 81/100
# 112/112 - 0s - loss: 0.1367
# Epoch 82/100
# 112/112 - 0s - loss: 0.1318
# Epoch 83/100
# 112/112 - 0s - loss: 0.1315
# Epoch 84/100
# 112/112 - 0s - loss: 0.1280
# Epoch 85/100
# 112/112 - 0s - loss: 0.1287
# Epoch 86/100
# 112/112 - 0s - loss: 0.1279
# Epoch 87/100
# 112/112 - 0s - loss: 0.1229
# Epoch 88/100
# 112/112 - 0s - loss: 0.1232
# Epoch 89/100
# 112/112 - 0s - loss: 0.1192
# Epoch 90/100
# 112/112 - 0s - loss: 0.1195
# Epoch 91/100
# 112/112 - 0s - loss: 0.1203
# Epoch 92/100
# 112/112 - 0s - loss: 0.1160
# Epoch 93/100
# 112/112 - 0s - loss: 0.1156
# Epoch 94/100
# 112/112 - 0s - loss: 0.1154
# Epoch 95/100
# 112/112 - 0s - loss: 0.1131
# Epoch 96/100
# 112/112 - 0s - loss: 0.1110
# Epoch 97/100
# 112/112 - 0s - loss: 0.1144
# Epoch 98/100
# 112/112 - 0s - loss: 0.1085
# Epoch 99/100
# 112/112 - 0s - loss: 0.1107
# Epoch 100/100
# 112/112 - 0s - loss: 0.1092

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(x_test)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y_test,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Accuracy: {correct}")
# Out:
# W0819 15:14:30.387507 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Accuracy: 1.0

# %%
# Rank the features
from IPython.display import display, HTML

names = list(df.columns) # x+y column names
names.remove("species") # remove the target(y)
rank = perturbation_rank(model, x_test, y_test, names, False)
display(rank)
# Out:
# W0819 15:14:30.444489 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:30.453488 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:30.461488 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:30.471489 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
#       name     error  importance
# 0  petal_l  2.846739    1.000000
# 1  petal_w  0.671724    0.235963
# 2  sepal_l  0.141148    0.049582
# 3  sepal_w  0.091809    0.032250

# %% [markdown]
# ### Regression and Input Perturbation Ranking

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

save_path = "."

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train,y_train,verbose=2,epochs=100)

# Predict
pred = model.predict(x)
# Out:
# W0819 15:14:30.628494 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Epoch 1/100
# 298/298 - 0s - loss: 1559.2899
# Epoch 2/100
# 298/298 - 0s - loss: 443.0820
# Epoch 3/100
# 298/298 - 0s - loss: 300.1852
# Epoch 4/100
# 298/298 - 0s - loss: 253.6714
# Epoch 5/100
# 298/298 - 0s - loss: 187.6016
# Epoch 6/100
# 298/298 - 0s - loss: 183.5883
# Epoch 7/100
# 298/298 - 0s - loss: 183.9289
# Epoch 8/100
# 298/298 - 0s - loss: 167.7776
# Epoch 9/100
# 298/298 - 0s - loss: 160.7908
# Epoch 10/100
# 298/298 - 0s - loss: 155.8137
# Epoch 11/100
# 298/298 - 0s - loss: 149.1986
# Epoch 12/100
# 298/298 - 0s - loss: 144.5110
# Epoch 13/100
# 298/298 - 0s - loss: 139.0513
# Epoch 14/100
# 298/298 - 0s - loss: 136.2702
# Epoch 15/100
# 298/298 - 0s - loss: 136.8744
# Epoch 16/100
# 298/298 - 0s - loss: 127.1330
# Epoch 17/100
# 298/298 - 0s - loss: 132.9591
# Epoch 18/100
# 298/298 - 0s - loss: 128.9401
# Epoch 19/100
# 298/298 - 0s - loss: 115.0540
# Epoch 20/100
# 298/298 - 0s - loss: 111.8599
# Epoch 21/100
# 298/298 - 0s - loss: 115.3871
# Epoch 22/100
# 298/298 - 0s - loss: 106.7886
# Epoch 23/100
# 298/298 - 0s - loss: 101.2296
# Epoch 24/100
# 298/298 - 0s - loss: 100.4774
# Epoch 25/100
# 298/298 - 0s - loss: 97.5229
# Epoch 26/100
# 298/298 - 0s - loss: 93.4279
# Epoch 27/100
# 298/298 - 0s - loss: 93.8727
# Epoch 28/100
# 298/298 - 0s - loss: 89.8434
# Epoch 29/100
# 298/298 - 0s - loss: 91.6693
# Epoch 30/100
# 298/298 - 0s - loss: 87.4931
# Epoch 31/100
# 298/298 - 0s - loss: 89.6551
# Epoch 32/100
# 298/298 - 0s - loss: 82.5026
# Epoch 33/100
# 298/298 - 0s - loss: 88.1567
# Epoch 34/100
# 298/298 - 0s - loss: 91.1699
# Epoch 35/100
# 298/298 - 0s - loss: 96.9902
# Epoch 36/100
# 298/298 - 0s - loss: 96.0484
# Epoch 37/100
# 298/298 - 0s - loss: 89.2738
# Epoch 38/100
# 298/298 - 0s - loss: 75.7954
# Epoch 39/100
# 298/298 - 0s - loss: 73.3345
# Epoch 40/100
# 298/298 - 0s - loss: 74.2692
# Epoch 41/100
# 298/298 - 0s - loss: 74.6573
# Epoch 42/100
# 298/298 - 0s - loss: 70.3825
# Epoch 43/100
# 298/298 - 0s - loss: 65.6756
# Epoch 44/100
# 298/298 - 0s - loss: 63.5143
# Epoch 45/100
# 298/298 - 0s - loss: 63.1461
# Epoch 46/100
# 298/298 - 0s - loss: 61.5945
# Epoch 47/100
# 298/298 - 0s - loss: 60.8559
# Epoch 48/100
# 298/298 - 0s - loss: 60.9447
# Epoch 49/100
# 298/298 - 0s - loss: 58.8260
# Epoch 50/100
# 298/298 - 0s - loss: 65.2873
# Epoch 51/100
# 298/298 - 0s - loss: 61.4850
# Epoch 52/100
# 298/298 - 0s - loss: 76.4146
# Epoch 53/100
# 298/298 - 0s - loss: 66.9197
# Epoch 54/100
# 298/298 - 0s - loss: 54.8163
# Epoch 55/100
# 298/298 - 0s - loss: 55.1214
# Epoch 56/100
# 298/298 - 0s - loss: 50.5856
# Epoch 57/100
# 298/298 - 0s - loss: 50.2830
# Epoch 58/100
# 298/298 - 0s - loss: 49.6034
# Epoch 59/100
# 298/298 - 0s - loss: 48.8089
# Epoch 60/100
# 298/298 - 0s - loss: 47.4670
# Epoch 61/100
# 298/298 - 0s - loss: 45.9854
# Epoch 62/100
# 298/298 - 0s - loss: 43.3706
# Epoch 63/100
# 298/298 - 0s - loss: 42.6222
# Epoch 64/100
# 298/298 - 0s - loss: 42.4879
# Epoch 65/100
# 298/298 - 0s - loss: 44.4657
# Epoch 66/100
# 298/298 - 0s - loss: 42.8027
# Epoch 67/100
# 298/298 - 0s - loss: 46.7832
# Epoch 68/100
# 298/298 - 0s - loss: 42.7598
# Epoch 69/100
# 298/298 - 0s - loss: 39.2589
# Epoch 70/100
# 298/298 - 0s - loss: 40.6138
# Epoch 71/100
# 298/298 - 0s - loss: 40.9221
# Epoch 72/100
# 298/298 - 0s - loss: 35.5641
# Epoch 73/100
# 298/298 - 0s - loss: 36.4354
# Epoch 74/100
# 298/298 - 0s - loss: 35.6893
# Epoch 75/100
# 298/298 - 0s - loss: 34.6530
# Epoch 76/100
# 298/298 - 0s - loss: 32.8944
# Epoch 77/100
# 298/298 - 0s - loss: 33.5579
# Epoch 78/100
# 298/298 - 0s - loss: 31.5365
# Epoch 79/100
# 298/298 - 0s - loss: 31.0707
# Epoch 80/100
# 298/298 - 0s - loss: 32.3957
# Epoch 81/100
# 298/298 - 0s - loss: 31.6181
# Epoch 82/100
# 298/298 - 0s - loss: 29.7164
# Epoch 83/100
# 298/298 - 0s - loss: 29.7082
# Epoch 84/100
# 298/298 - 0s - loss: 28.9681
# Epoch 85/100
# 298/298 - 0s - loss: 29.1248
# Epoch 86/100
# 298/298 - 0s - loss: 27.4652
# Epoch 87/100
# 298/298 - 0s - loss: 27.6053
# Epoch 88/100
# 298/298 - 0s - loss: 26.4133
# Epoch 89/100
# 298/298 - 0s - loss: 25.0738
# Epoch 90/100
# 298/298 - 0s - loss: 25.3491
# Epoch 91/100
# 298/298 - 0s - loss: 25.3465
# Epoch 92/100
# 298/298 - 0s - loss: 24.3639
# Epoch 93/100
# 298/298 - 0s - loss: 23.8985
# Epoch 94/100
# 298/298 - 0s - loss: 23.1552
# Epoch 95/100
# 298/298 - 0s - loss: 23.1016
# Epoch 96/100
# 298/298 - 0s - loss: 23.2722
# Epoch 97/100
# 298/298 - 0s - loss: 22.0348
# Epoch 98/100
# 298/298 - 0s - loss: 23.9377
# Epoch 99/100
# 298/298 - 0s - loss: 22.6452
# Epoch 100/100
# 298/298 - 0s - loss: 21.8604
# W0819 15:14:32.600543 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.

# %%
# Rank the features
from IPython.display import display, HTML

names = list(df.columns) # x+y column names
names.remove("name")
names.remove("mpg") # remove the target(y)
rank = perturbation_rank(model, x_test, y_test, names, True)
display(rank)
# Out:
# W0819 15:14:32.645547 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.656546 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.665548 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.674548 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.683545 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.692548 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:32.701548 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
#            name       error  importance
# 0  displacement  127.022319    1.000000
# 1        weight   33.068019    0.260332
# 2          year   24.988007    0.196721
# 3    horsepower   20.419030    0.160752
# 4  acceleration   18.785670    0.147893
# 5        origin   18.560458    0.146120
# 6     cylinders   18.292052    0.144007

# %% [markdown]
# ### Biological Response with Neural Network
#
# * [Predicting a Biological Response](https://www.kaggle.com/c/bioresponse)

# %%
import pandas as pd
import os
import numpy as np
from sklearn import metrics
from scipy.stats import zscore
from sklearn.model_selection import KFold
from IPython.display import HTML, display

path = "./data/"

filename_train = os.path.join(path,"bio_train.csv")
filename_test = os.path.join(path,"bio_test.csv")
filename_submit = os.path.join(path,"bio_submit.csv")

df_train = pd.read_csv(filename_train,na_values=['NA','?'])
df_test = pd.read_csv(filename_test,na_values=['NA','?'])

activity_classes = df_train['Activity']

# %%
print(df_train.shape)
# Out:
# (3751, 1777)

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import sklearn

# Encode feature vector
# Convert to numpy - Classification
x_columns = df_train.columns.drop('Activity')
x = df_train[x_columns].values
y = df_train['Activity'].values # Classification
x_submit = df_test[x_columns].values.astype(np.float32)


# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42) 

print("Fitting/Training...")
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu'))
model.add(Dense(10))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
model.fit(x_train,y_train,validation_data=(x_test,y_test),callbacks=[monitor],verbose=0,epochs=1000)
print("Fitting done...")

# Predict
pred = model.predict(x_test).flatten()


# Clip so that min is never exactly 0, max never 1
pred = np.clip(pred,a_min=1e-6,a_max=(1-1e-6)) 
print("Validation logloss: {}".format(sklearn.metrics.log_loss(y_test,pred)))

# Evaluate success using accuracy
pred = pred>0.5 # If greater than 0.5 probability, then true
score = metrics.accuracy_score(y_test, pred)
print("Validation accuracy score: {}".format(score))

# Build real submit file
pred_submit = model.predict(x_submit)

# Clip so that min is never exactly 0, max never 1 (would be a NaN score)
pred = np.clip(pred,a_min=1e-6,a_max=(1-1e-6)) 
submit_df = pd.DataFrame({'MoleculeId':[x+1 for x in range(len(pred_submit))],'PredictedProbability':pred_submit.flatten()})
submit_df.to_csv(filename_submit, index=False)
# Out:
# W0819 15:14:34.957605 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:35.015625 12720 deprecation.py:323] From C:\Users\jheaton\AppData\Local\Continuum\miniconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Fitting/Training...
# W0819 15:14:37.226079 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.304084 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Epoch 00007: early stopping
# Fitting done...
# Validation logloss: 0.5580600737567578
# Validation accuracy score: 0.7633262260127932

# %% [markdown]
# ### What Features/Columns are Important
# The following uses perturbation ranking to evaluate the neural network.

# %%
# Rank the features
from IPython.display import display, HTML

names = list(df_train.columns) # x+y column names
names.remove("Activity") # remove the target(y)
rank = perturbation_rank(model, x_test, y_test, names, False)
display(rank)
# Out:
# W0819 15:14:37.532091 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.579099 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.621090 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.664100 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.705101 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.749103 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.792104 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.840097 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.886246 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.930247 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:37.974247 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.017249 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.061250 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.104253 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.146253 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.188254 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.231254 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.274256 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.318258 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.361258 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.403259 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.445249 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.488260 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.532262 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.575256 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.625268 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.666254 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.711256 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.759257 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.801269 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.843271 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.884272 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.927273 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:38.970262 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.013276 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.055276 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.099277 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.147278 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.190279 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.232280 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.275280 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.318281 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.361285 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.405286 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.448287 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.492743 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.535744 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.579745 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.622746 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.673736 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.717748 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.761739 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.807470 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.848460 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.892464 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.935474 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:39.978475 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.021475 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.063478 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.107467 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.149478 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.191480 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.234482 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.276482 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.318484 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.360487 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.414477 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.461476 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.503479 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.549480 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.593478 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.639480 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.680481 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.726482 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.770485 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.811489 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.851486 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.892486 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.933499 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:40.975500 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.016500 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.060502 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.103493 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.145492 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.186506 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.228507 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.270509 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.312509 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.354511 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.398505 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.442511 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.490514 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.531513 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.573514 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.615518 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.656517 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.697509 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.738520 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.778522 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.820523 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.862524 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.904525 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.947525 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:41.989526 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.031517 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.075531 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.118531 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.162520 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.207523 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.250522 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.294523 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.337536 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.380537 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.421542 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.465926 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.508841 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.550842 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.593843 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.635845 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.677846 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.723846 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.765847 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.805849 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.847849 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.888851 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.929853 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:42.970853 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.012854 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.053855 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.096857 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.137858 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.179858 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.220859 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.261860 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.302861 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.343862 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.384861 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.425865 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.465865 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.506869 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.546868 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.587869 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.628868 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.668870 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.708877 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.750873 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.791874 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.831875 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.872876 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.912878 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.953881 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:43.995868 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.035881 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.077881 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.122883 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.164883 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.206885 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.248887 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.289887 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.329888 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.374892 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.418891 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.459891 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.501892 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.542894 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.582895 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.622896 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.663897 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.703897 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.745898 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.785900 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.826902 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.867903 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.907903 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.948904 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:44.988907 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.029906 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.071908 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.112909 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.153910 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.195910 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.236912 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.277912 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.318914 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.358915 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.400905 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.440917 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.481907 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.522918 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.562923 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.602921 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.643923 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.684925 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.726913 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.767925 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.807928 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.848927 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.888930 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.929929 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:45.970930 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.011931 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.053933 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.093936 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.135938 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.176936 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.217938 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.259938 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.299940 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.340940 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.381935 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.422942 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.463944 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.503944 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.546948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.588946 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.631948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.673949 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.716950 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.758940 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.800953 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.841943 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.884954 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.926956 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:46.967958 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.009958 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.050958 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.091959 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.133960 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.174645 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.215645 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.257646 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.299636 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.341647 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.381636 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.422638 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.462650 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.503642 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.544653 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.584654 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.625654 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.666657 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.706660 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.747658 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.788715 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.829715 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.870301 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.911301 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.952303 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:47.993303 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.037304 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.077305 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.118309 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.158308 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.198309 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.239309 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.280311 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.320312 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.361191 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.401189 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.441190 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.482191 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.522192 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.563194 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.604194 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.644196 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.685197 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.725197 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.766187 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.806197 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.848188 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.895202 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.937204 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:48.985661 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.026674 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.072673 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.115675 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.160676 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.205676 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.247677 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:14:49.288679 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# ...
# W0819 15:15:48.387334 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.428335 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.471328 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.512336 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.553338 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.594339 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.635328 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.676334 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.718341 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.760343 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.802345 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.844348 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.885346 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.928384 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:48.969384 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.009387 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.051069 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.092069 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.134071 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.176072 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.218072 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.260073 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.302074 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.343068 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.385076 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.429067 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.471077 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.513073 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.554081 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.597083 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.638083 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.680083 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.723084 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.771413 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.814413 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.855412 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.895416 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.936417 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:49.979417 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.020429 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.063072 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.109071 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.150061 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.191672 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.233672 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.274961 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.316958 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.356960 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.397964 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.438966 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.480967 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.522974 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.564968 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.605970 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.647971 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.688979 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.730972 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.773975 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.818975 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.859973 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.901303 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.944091 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:50.986093 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.026094 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.068094 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.115095 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.157096 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.198931 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.240923 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.282926 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.324926 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.366934 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.408929 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.456926 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.498930 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.538929 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.580933 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.621934 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.662935 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.705943 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.747938 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.790945 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.836939 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.877948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.920948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:51.962950 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:52.003951 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:52.045952 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:52.087946 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:52.129946 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:52.172948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
#        name     error  importance
# 0       D27  0.620942    1.000000
# 1     D1188  0.567100    0.913289
# 2      D998  0.564381    0.908910
# 3     D1059  0.564303    0.908784
# 4     D1049  0.563695    0.907807
# ...     ...       ...         ...
# 1771  D1442  0.554007    0.892204
# 1772  D1407  0.553966    0.892138
# 1773  D1681  0.553890    0.892016
# 1774  D1415  0.552120    0.889166
# 1775  D1286  0.551627    0.888371
#
# [1776 rows x 3 columns]

# %% [markdown]
# ### Neural Network Ensemble
#
# A neural network ensemble combines neural network predictions with other models. The exact blend of all of these models is determined by logistic regression. The following code performs this blend for a classification.

# %%
import numpy as np
import os
import pandas as pd
import math
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

PATH = "./data/"
SHUFFLE = False
FOLDS = 10

def build_ann(input_size,classes,neurons):
    model = Sequential()
    model.add(Dense(neurons, input_dim=input_size, activation='relu'))
    model.add(Dense(1))
    model.add(Dense(classes,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    return model

def mlogloss(y_test, preds):
    epsilon = 1e-15
    sum = 0
    for row in zip(preds,y_test):
        x = row[0][row[1]]
        x = max(epsilon,x)
        x = min(1-epsilon,x)
        sum+=math.log(x)
    return( (-1/len(preds))*sum)

def stretch(y):
    return (y - y.min()) / (y.max() - y.min())


def blend_ensemble(x, y, x_submit):
    kf = StratifiedKFold(FOLDS)
    folds = list(kf.split(x,y))

    models = [
        KerasClassifier(build_fn=build_ann,neurons=20,input_size=x.shape[1],classes=2),
        KNeighborsClassifier(n_neighbors=3),
        RandomForestClassifier(n_estimators=100, n_jobs=-1, criterion='gini'),
        RandomForestClassifier(n_estimators=100, n_jobs=-1, criterion='entropy'),
        ExtraTreesClassifier(n_estimators=100, n_jobs=-1, criterion='gini'),
        ExtraTreesClassifier(n_estimators=100, n_jobs=-1, criterion='entropy'),
        GradientBoostingClassifier(learning_rate=0.05, subsample=0.5, max_depth=6, n_estimators=50)]

    dataset_blend_train = np.zeros((x.shape[0], len(models)))
    dataset_blend_test = np.zeros((x_submit.shape[0], len(models)))

    for j, model in enumerate(models):
        print("Model: {} : {}".format(j, model) )
        fold_sums = np.zeros((x_submit.shape[0], len(folds)))
        total_loss = 0
        for i, (train, test) in enumerate(folds):
            x_train = x[train]
            y_train = y[train]
            x_test = x[test]
            y_test = y[test]
            model.fit(x_train, y_train)
            pred = np.array(model.predict_proba(x_test))
            # pred = model.predict_proba(x_test)
            dataset_blend_train[test, j] = pred[:, 1]
            pred2 = np.array(model.predict_proba(x_submit))
            #fold_sums[:, i] = model.predict_proba(x_submit)[:, 1]
            fold_sums[:, i] = pred2[:, 1]
            loss = mlogloss(y_test, pred)
            total_loss+=loss
            print("Fold #{}: loss={}".format(i,loss))
        print("{}: Mean loss={}".format(model.__class__.__name__,total_loss/len(folds)))
        dataset_blend_test[:, j] = fold_sums.mean(1)

    print()
    print("Blending models.")
    blend = LogisticRegression(solver='lbfgs')
    blend.fit(dataset_blend_train, y)
    return blend.predict_proba(dataset_blend_test)

if __name__ == '__main__':

    np.random.seed(42)  # seed to shuffle the train set

    print("Loading data...")
    filename_train = os.path.join(PATH, "bio_train.csv")
    df_train = pd.read_csv(filename_train, na_values=['NA', '?'])

    filename_submit = os.path.join(PATH, "bio_test.csv")
    df_submit = pd.read_csv(filename_submit, na_values=['NA', '?'])

    predictors = list(df_train.columns.values)
    predictors.remove('Activity')
    x = df_train[predictors].values
    y = df_train['Activity']
    x_submit = df_submit.values

    if SHUFFLE:
        idx = np.random.permutation(y.size)
        x = x[idx]
        y = y[idx]

    submit_data = blend_ensemble(x, y, x_submit)
    submit_data = stretch(submit_data)

    ####################
    # Build submit file
    ####################
    ids = [id+1 for id in range(submit_data.shape[0])]
    submit_filename = os.path.join(PATH, "bio_submit.csv")
    submit_df = pd.DataFrame({'MoleculeId': ids, 'PredictedProbability': submit_data[:, 1]},
                             columns=['MoleculeId','PredictedProbability'])
    submit_df.to_csv(submit_filename, index=False)
# Out:
# Loading data...
# Model: 0 : <tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x000001962E56C9B0>
# W0819 15:15:55.228026 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3375/3375 [==============================] - 1s 177us/sample - loss: 0.6070
# W0819 15:15:55.831674 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:55.875673 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #0: loss=0.5540271252836152
# W0819 15:15:56.294684 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3375/3375 [==============================] - 0s 147us/sample - loss: 0.6303
# W0819 15:15:56.795923 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:56.836932 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #1: loss=0.5445477180683725
# W0819 15:15:57.260947 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3375/3375 [==============================] - 0s 147us/sample - loss: 0.6088
# W0819 15:15:57.760948 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:57.803957 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #2: loss=0.5401721048981553
# W0819 15:15:58.222973 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3375/3375 [==============================] - 1s 181us/sample - loss: 0.5985
# W0819 15:15:58.837977 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:58.880986 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #3: loss=0.4995116027234963
# W0819 15:15:59.298736 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3376/3376 [==============================] - 1s 149us/sample - loss: 0.6074
# W0819 15:15:59.808040 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:15:59.852048 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #4: loss=0.552265225014246
# W0819 15:16:00.273070 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3376/3376 [==============================] - 1s 180us/sample - loss: 0.5967
# W0819 15:16:00.884081 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:16:00.929075 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #5: loss=0.5920530577133667
# W0819 15:16:01.352097 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3376/3376 [==============================] - 0s 147us/sample - loss: 0.5912
# W0819 15:16:01.852018 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:16:01.896020 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #6: loss=0.5066588401181843
# W0819 15:16:02.313030 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3377/3377 [==============================] - 0s 144us/sample - loss: 0.6281
# W0819 15:16:02.804981 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:16:02.971660 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #7: loss=0.5611699477808485
# W0819 15:16:03.392671 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3377/3377 [==============================] - 0s 146us/sample - loss: 0.6233
# W0819 15:16:03.889980 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:16:03.932979 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #8: loss=0.5665587789108542
# W0819 15:16:04.351011 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 3377/3377 [==============================] - 0s 146us/sample - loss: 0.6127
# W0819 15:16:04.848786 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# W0819 15:16:04.890800 12720 training_utils.py:1210] When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# Fold #9: loss=0.5394746160266767
# KerasClassifier: Mean loss=0.5456439016537816
# Model: 1 : KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')
# Fold #0: loss=3.606678388314123
# Fold #1: loss=2.2197228940978317
# Fold #2: loss=3.6717523663107237
# Fold #3: loss=2.5045156203944594
# Fold #4: loss=4.443553550438037
# Fold #5: loss=4.410524301688227
# Fold #6: loss=3.400455469543658
# Fold #7: loss=3.0885474338547683
# Fold #8: loss=2.1219335323249253
# Fold #9: loss=3.0613772690497245
# KNeighborsClassifier: Mean loss=3.2529060826016476
# Model: 2 : RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)
# Fold #0: loss=0.4657177982691548
# Fold #1: loss=0.426532747936268
# Fold #2: loss=0.5555646241353958
# Fold #3: loss=0.4158839384284288
# Fold #4: loss=0.47983725577294734
# Fold #5: loss=0.4816998209698582
# Fold #6: loss=0.40791842169050496
# Fold #7: loss=0.4769556823742715
# Fold #8: loss=0.45170716330819044
# Fold #9: loss=0.4679788790578769
# RandomForestClassifier: Mean loss=0.4629796331942897
# Model: 3 : RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)
# Fold #0: loss=0.4511847247326708
# Fold #1: loss=0.42856095931249005
# Fold #2: loss=0.48374399227671866
# Fold #3: loss=0.41861499005015385
# Fold #4: loss=0.4815877201194617
# Fold #5: loss=0.4978144986688418
# Fold #6: loss=0.40096963197346613
# Fold #7: loss=0.4546784305314136
# Fold #8: loss=0.4465855989880112
# Fold #9: loss=0.4695067213178049
# RandomForestClassifier: Mean loss=0.45332472679710323
# Model: 4 : ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
# Fold #0: loss=0.45496751079363495
# Fold #1: loss=0.4221988146584036
# Fold #2: loss=0.5864779075767735
# Fold #3: loss=0.4135387147555288
# Fold #4: loss=0.49165543640777337
# Fold #5: loss=0.5826853127129209
# Fold #6: loss=0.4992293347545809
# Fold #7: loss=0.5696776278324083
# Fold #8: loss=0.5377009614825886
# Fold #9: loss=0.6233110429105153
# ExtraTreesClassifier: Mean loss=0.5181442663885129
# Model: 5 : ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
# Fold #0: loss=0.44825346440152214
# Fold #1: loss=0.40736044850901787
# Fold #2: loss=0.5775460796610716
# Fold #3: loss=0.42126274280011555
# Fold #4: loss=0.4949968282719872
# Fold #5: loss=0.5074636989761913
# Fold #6: loss=0.4176899941799664
# Fold #7: loss=0.6431685288404098
# Fold #8: loss=0.5444145998368657
# Fold #9: loss=0.46770812815232515
# ExtraTreesClassifier: Mean loss=0.4929864513629473
# Model: 6 : GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.05, loss='deviance', max_depth=6,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=50,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=0.5, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
# Fold #0: loss=0.4804937760760543
# Fold #1: loss=0.4581518207794376
# Fold #2: loss=0.48285850183766754
# Fold #3: loss=0.4399317867686944
# Fold #4: loss=0.498996013541783
# Fold #5: loss=0.5045013322264401
# Fold #6: loss=0.45389969767473726
# Fold #7: loss=0.4623607887672741
# Fold #8: loss=0.4551702632706958
# Fold #9: loss=0.4709134176721333
# GradientBoostingClassifier: Mean loss=0.47072773986149186
#
# Blending models.
